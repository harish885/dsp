# %%
if 10 > 58:
    print("Ten is greater than five!")
print("Ten is lesser than five!")
# Out:
# Ten is lesser than five!

# %%
if 10 > 58:
    print("Ten is greater than five!")
else:
    print("Ten is lower")

print("today is sunny")
# Out:
# Ten is lower
# today is sunny

# %%
def sum(a,b):
    """
    This is a function called sum
    which adds two values!!!!
    """
    result = a+b #sum of two variables
    return result # we return the result

# %%
sum(10,20)
# Out:
# 30

# %%
sum("Kit", "Kat") #adding of strings
# Out:
# 'KitKat'
