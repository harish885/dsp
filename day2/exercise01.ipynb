# %%
if 10 > 58:
    print("Ten is greater than five!")
print("Ten is lesser than five!")
# Out:
# Ten is lesser than five!

# %%
if 10 > 58:
    print("Ten is greater than five!")
else:
    print("Ten is lower")

print("today is sunny")
# Out:
# Ten is lower
# today is sunny

# %%
def sum(a,b):
    """
    This is a function called sum
    which adds two values!!!!
    """
    result = a+b #sum of two variables
    return result # we return the result

# %%
sum(10,20)
# Out:
# 30

# %%
sum("Kit", "Kat") #adding of strings
# Out:
# 'KitKat'

# %%
age = 30 # variables are placeholders for storing data values
Age = 20 # here "age" is different than "Age"; because python is case-sensitive

# %%
building1 = "Church"
building_0 = "Temple"
building_height = 150

# %% [markdown]
# It is always good practice to have the variable names as consistent

# %%
building1_name = "Church" # snake syntax
building1Name = "Church" # camel syntax
building1_height = 100

building2_name = "Stadium"
building2_height = 150

building3_name = "Temple"
building3_height = 300

# %%
name = "harish"

name = harish #this gives error because, harish is not a variable "yet"

# %%
type(building1_name) #it tells the type of a variable name
type(age)
# Out:
# int

# %%
dangerous = True

# %%
type(dangerous)
# Out:
# bool

# %%
type(3<5)
# Out:
# bool

# %%
d = str(dangerous) #converting the variable of "dangerous" into a string

# %%
d
# Out:
# 'True'

# %%
type(d) # d is a string, since the result "True" is converted into a string.
# Out:
# str

# %%
s = "200"

# %%
int(s) + int(s)
# Out:
# 400

# %% [markdown]
# DEMO

# %%
a = 10
b = "Harish"
c = True
d = 5.5

#Different data types of variables

# %%
maxdistance = 100
Temperature = 98.5
greet_ing = "Hello"
isRaining = False

# %%
first_value = 100
total_amount = 120.00
calc_num = 250
data_entry = "Harish"

# %%
num = 100.2
float(num)
# Out:
# 100.2

# %%
type(num)
# Out:
# float

# %%
num1 = 3.14159
int(num1)
# Out:
# 3

# %%
type(num1)
# Out:
# float

# %%
num3 = 99.99

# %%
str(num3)
# Out:
# '99.99'

# %%
type(num3)
# Out:
# float

# %%
print(num3)
# Out:
# 99.99

# %%
print(type(num3))
# Out:
# <class 'float'>
