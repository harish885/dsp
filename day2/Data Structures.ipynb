# %% [markdown]
# ## LISTS

# %%
my_list = ["Apple","Banana","Peach",4]

# %%
my_list[3]
# Out:
# 4

# %%
my_list[3] = "Mango"

# %%
print(my_list)
# Out:
# ['Apple', 'Banana', 'Peach', 'Mango']

# %%
print(f"my favorite fruits are {my_list}")
# Out:
# my favorite fruits are ['Apple', 'Banana', 'Peach', 'Mango']

# %%
my_list.append('Guava')

# %%
print(f"my favorite fruits are {my_list}")
# Out:
# my favorite fruits are ['Apple', 'Banana', 'Peach', 'Mango', 'Guava']

# %%
my_list.remove('Banana')

# %%
print("my favorite fruits are", my_list)
# Out:
# my favorite fruits are ['Apple', 'Peach', 'Mango', 'Guava']

# %%
my_list.pop(0)
# Out:
# 'Apple'

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Guava']

# %%
print("my favorite fruits are", my_list[0] == "Peach")
# Out:
# my favorite fruits are True

# %%
my_list.append(2)

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Guava', 2]

# %%
my_list.remove(2) #this removes the string or number 2 from the list

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Guava']

# %%
my_list.remove(my_list[2]) # this removes the 2nd element of list

# %%
my_list
# Out:
# ['Peach', 'Mango']

# %%
def insert_at(my_list, position, e):
    return my_list[:position] + [e] + my_list[position:]

# %%
my_list = insert_at(my_list,2, "Apple")

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Apple']

# %%
my_list = insert_at(my_list,2, "Banana")

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Banana', 'Apple']

# %%
my_list.insert(3, "Guava")

# %%
my_list
# Out:
# ['Peach', 'Mango', 'Banana', 'Guava', 'Apple']

# %% [markdown]
# ## TUPLES

# %%
my_tuple = ("Apple", "Banana", "Mango")
print(my_tuple)
# Out:
# ('Apple', 'Banana', 'Mango')
