# %% [markdown]
# # Error Handling

# %%
try:
    x = 3 / 0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    x = 10 + "abc"
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    my_list = [1,2,3,4,5]
    print(my_list[10])
except Exception as e:
    print(e)
# Out:
# list index out of range
