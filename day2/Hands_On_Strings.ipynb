# %% [markdown]
# # Create strings using different quotes

# %%
name1 = "Harish!"
name2 = 'Harish'
name3 = 'My name is harish"'
name4 = '''My name is harish
and i am working on different quotes
on strings'''

print(name1)
print(name2)
print(name3)
print(name4)
# Out:
# Harish!
# Harish
# My name is harish"
# My name is harish
# and i am working on different quotes
# on strings

# %% [markdown]
# # Use string methods to transform and analyse strings

# %%
user = "Harish"
#Given a string, build another string made of first and last two characters
result = user[0] + user[-1]
result
# Out:
# 'Hh'

# %% [markdown]
# # Practice String formatting with different methods

# %%
user = "Harish"
low = user[:2].lower() #first two characters are lower case
up = user[-2:].upper() # last two characters are upper case

final = low+up
final
# Out:
# 'haSH'

# %% [markdown]
# # Perform string concatenation and slicing

# %%
b = "How are you?"
b[3:8] #the string slices from 3rd character to 8th character

c = "How are you Mr."
d = "Harish"
#usage of f strings

print(f"{c}{d}")
# Out:
# How are you Mr.Harish
