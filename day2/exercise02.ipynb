# %%
def is_even(a):
    """
    this function returns a True if the given number is even,
    or it returns False
    """
    result = a % 2
    if result == 1:
        return False
    else:
        return True

# %%
is_even(10)
# Out:
# True

# %%
def is_even_2(a):
    """
    this function returns a True if the given number is even,
    or it returns False
    """
    if a % 2 == 1:
        return False
    else:
        return True

# %%
is_even_2(25)
# Out:
# False

# %%
def is_even_3(a):
    """
    this function returns a True if the given number is even,
    or it returns False
    """
    return (a % 2 == 0) # returns true if the result is zero or otherwise false, because it is a boolean

# %%
is_even_3(1)
# Out:
# False

# %%
20/3 # normal division
# Out:
# 6.666666666666667

# %%
20 // 3 # floor division
# Out:
# 6

# %%
a = 10
b = 5

a += b # equivalent to "a = a+b"
a
a += 5
a
# Out:
# 20

# %%
a == b
# Out:
# False

# %%
a != b # a is 20, b is 5
# Out:
# True
